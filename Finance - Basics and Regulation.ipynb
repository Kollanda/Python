# %% [markdown]
# # Finance basics and regulation

# %% [markdown]
# # UK Regulatory landscape
# [FSA UK 2012 Clifford Chance](https://www.google.co.uk/url?sa=i&source=images&cd=&ved=2ahUKEwi6n5eDm4bfAhWuyYUKHSPeCdsQjhx6BAgBEAI&url=https%3A%2F%2Fonlineservices.cliffordchance.com%2Fonline%2FfreeDownload.action%3Fkey%3DOBWIbFgNhLNomwBl%252B33QzdFhRQAhp8D%252BxrIGReI2crGqLnALtlyZe7NckjrpjgUOHpxvSAvxk%252BHp%250D%250A5mt12P8Wnx03DzsaBGwsIB3EVF8XihbSpJa3xHNE7tFeHpEbaeIf%26attachmentsize%3D132856&psig=AOvVaw088WIftcFkWefAV_EonOxh&ust=1544014122200437)
# ![image.png](attachment:image.png)
# # same on P. 98 IMC Volume 1

# %% [markdown]
# Proprietary Trading strategies:
# - directional, long, short
# - arbitrage
# difference from deteriminstic mathemetical relationship: e.g. forward price relation to spot price (covered interest rate parity)
# - value, relative value
# - sytematic, momentum, statistical arbitrage
# - fundamental analysis, global macro
# trade balance, earning potential, policy change or environment
# - special situations, distressed (Bain capital)
# ### check out CFA

# %% [markdown]
# # Behavioural economics
# JKU course

# %% [markdown]
# # Leveraged ETF problem
# {CRR ROLL } >> Roll yield (or cost) >> adjustment to reflect the real cost ETF needs to manage this roll >>  {NSN O7U8FS6TTDSX <Go>} >> problem with leveraged ETF is daily resetting >> screws up your daily return
