# %% [markdown]
#
# [MIT Topics in Mathematics with Applications in Finance](https://ocw.mit.edu/courses/mathematics/18-s096-topics-in-mathematics-with-applications-in-finance-fall-2013/video-lectures/)
# -> Intro: bear in mind: field developped in the last 30 odd years => dont ask if it is right or wrong in mathematics, but in physiscs: it is about participants, products, models, methodologies are still and constantly changing => No strategy will work forever: also if it would, by definition it will vanish by exploiting this opportunity
# match is needed BUT bear in mind it is more art than science - math is important but do not forget it is human beings behind it
# -> a lot of times a zero sum game but also facilitate borrowing and lending, so contributing to a well functioning economy
# -> **broker** does not take pricipal risk: only commission for bringing buyers and seller together
# -> market maker (most bank dealers are market makers) has principal risk but main source of profit is bid-offer

# %% [markdown]
# # Queue
# =BDP("IDRSGD Curncy","QUOTE_FACTOR")  quote factor {ADSK 766628551 766628557} JORGE ORTEGA 10:21:57 hello 10:21:58 checking 10:22:53 If we need to update the quotation factor of a currency, we do contact clients via DL and EPS 10:23:10 but there are many crosses that were initially scaled to accept more decimal precision 10:23:23 We do not contact clients when we create new tickers that are scaled 10:24:07 There is no list of tickers, you need to do SECF, collect a list of all crosses and then run FLDS DS672 in BPD 10:24:43 Yes, data and FX Business are responsible for any change to a existing ticker
#
#
#
#
#
# ECSU - .hardddata Index
#  60% is derived off the data on ffa Comdty ct <GO> from the Aril18 contract 98.62 which is implied rate (100-98.62) = 1.38% and the Jan18 contract 98.72 which is 1.28% s the 40% is (1.38-1.28) / 0.25 * 100 = 40% for no hike and hike is 100- 40% = 60%.
#
#
# Why delivery date for an option is different from the delivery date for a forward when we do manual  input of expiry term? Answer: For example, if you do {EUR Curncy OVML<GO>}, and enter 276D for expiry, you will get a different  delivery date from the one you'd get in {EUR Curncy OVML FWD<GO>} if you enter 276D. Essentially this is because for vanilla there's "expiry" (but not so for the forward), and the expiry  date would be 276D ahead of spot date, then there's another T+2 from expiry date to delivery date. For forward there's no "expiry", there's delivery instead. And this will be counted from spot date, in  example above 276D after spot date.  Refer to {FIFW DRQS 80370104<GO>} for explanation at length and also to {FIFW DRQS
# 80326050<GO>} for similar issue related to theta involving expiry-delivery time gap There are two types of time gap in OVML:  1. the time to expiry = Expiry Date - Price Date 2. the time to delivery = Delivery Date - Premium Date When you open a screen on a vanilla EUR for example, the 276 days correspond to  the time to expiry. If you switch the instrument type to a Forward, the 276 days will be interpreted as the time to delivery, considering there is no expiry for a Forward.  When you open an OVML screen with a Vanilla, then: 1. the Price Date is read from the screen 2. the Premium Date is computed from the Price Date (usually Price Date + 2  business days, but it depends on the currency pair) 3. the Expiry Date is computed from the time to expiry (for example 276 days)  and rolled to the next business day 4. the Delivery Date is computed from the Expiry Date (usually Expiry Date + 2  business days) If you open the screen with a Forward, then: 1. the Price Date is read from the screen 2. the Premium Date is computed as for a Vanilla 3. the Delivery Date is computed from the time to delivery (276 days) and rolled to the nearest business day.
#
# ### BLC calc setup DRQS 16350733
# replicate
# ### volume data
# - DES page BIS and the other stuff
# - SDRV
# - seperate pages: see BRD FAQ FX

# %% [markdown]
#  BLCP Bloomberg Spread Synthetic. BLCP allows the creation of a synthetic Onshore FX volatility surface based on the contributed data from Offshore FX volatility.
#
# {DOCS #2065541} explains the method.
#
# ADSK 792426322 792449830 for compound option explanation
#
#
# VEB= Venezuelan Bolivars. This currency has been discontinued due to inflation. The current one is VEF. VEF= Venezuelan Bolivar Fuerte = Actual currency. Each unit corresponds to 1000 VEB. Example: 1 VEF = 1000 VEB
#
# VEE= Venezuelan Essentials Rate. Imports designated as "non-essential" receive a rate of ~ 4.3 bolivares per dollar, a "essential" goods are exchanged at a rate of ~ 2.6. f you receive any clients contesting the VEB/VEF devaluation rates (looks like a massive spike), the quotes are valid, if you get any tickets you can adapt the message below:
#
# "The rates are correct. Venezuela announced the discontinuation of the DIPRO reference rate and adoption of DICOM rate, reason why the change in levels. Reference article: NSN {P3E27U3V7U9S <GO>}." change in VEF  Curncy ? 08/06 15:11:07 Please bear with me while I review 08/06 15:22:37 Please note that the redenomination date has been pushed out to 8/20 and will involve scaling by 5 decimal points. See https://cms.prod.bloomberg.com/team/display/fxpa/Venezuelan+Redenomination+From+VEF+to+VES for more details.
# 08/06 15:22:44 Also, https://www.currency-iso.org/en/shared/amendments/iso-4217-amendment.html for the update
#
#
# CLFUSD correct. The Chilean Unidad de Fomento (UF) is a real monetary unit based on the inflation rate
#
# The rate is quoted in Chilean pesos and fixed by the Central Bank of Chile.
#
# CLP Curncy621.82+.00(--) is the Chilean Peso
#
# if you only run CLF Curncy HP <GO> you see the conversion rate to the CLP ->  Price of 1 CLF in CLP

# %% [markdown]
# # ECON
# [Khan Academy](https://www.khanacademy.org/economics-finance-domain)
# [MIT Economics OCW](https://ocw.mit.edu/courses/#economics)
#
#
# ## Forecasts
# - Eco: short term
# - ECFC: Medium term
# - BI ECON: Long term
#
# ## Monetary policy
# ### Determining the interest rate
#
# - money multiplier and reserve ratio (more details in math and stats session)
# P. 71 onwards in Blanchard
# - add simply money multiplier example (like spreadhseet)
# ### the difference between BOE, ECB, FED and PBOC in a nutshell
# - note in BBG: add links to it
# - P. 789 Krugman Economics
# - P. 376 Krugman International Economics
#
# ## GDP
# - calculation: drugs and prostitution / Nigeria
# - special cases with X > GDP for some countries (P. 110 Blanchard)
# - GNP vs GDP and the current account (Ireland as an example) P. 861 Krugman
#
# - real vs nominal: P 594 - 595 Krugman
# - what real GDP doesnt measure: P 594 Krugman -> Human development report
#
#
# ## Inflation
# CPI and PCE There are a number of various metrics used for inflation.  One common measure if YoY CPI
#
# Headline BI ECONG 1098 |1098-2-M-Data|M12||PRC|R14 <GO>
#
# Core BI ECONG 1098 |1098-2-M-Units|M12||PRC|R156 <GO>
#
# You may also want to review ECOW <GO> ECST <GO> US Eco <GO> CPI time-series
#
# CPI CHNG Index CPUPXCHG Index CPI YOY  Index CPI XYOY Index CPUPAXFE Index CPURNSA  Index
#
#   Consumer Price Index (yoy %)   CPI YOY Index   CPI ex-Food & Energy (yoy %)   CPI XYOY Index
#
#   PCE Price Index (yoy %)   PCE DEFY Index   Core PCE Index (yoy %)   PCE CYOY Index
#
#   Consumer Price Index (mom %)   CPI CHNG Index   CPI ex-Food & Energy (mom %)   CPUPXCHG Index
#
#   The Philadelphia Fed is now generating a term structure of US inflation expectations, available at {ALLX FPIE <GO>}. For instance, {FPIE12MO Index <GO>} gives you inflation expectations for the next 12 months (1 year); {FPIE120M Index <GO>} gives you average inflation expectations for the next 120 months (10 years

# %% [markdown]
# BFIX: "{PROS N 48167 147251<GO>}" latest amendment to the methodology for TWAP was November 11 2015 per Stephen Mendolia. Link to story provided {NSN NXRUW96JIJUP <GO>}
#
#
# indices:
# - DXY  BBDxy
# - prove out BCWI
# - all others on BRD FAQ FX
#
# # FX
# ## The Foreign Exchange market
# ### Forward vs Futures
# exchange vs listed etc
# #### Futures
# P.702 Hodrick Marking to Market explained with example  - bring it into a panda DF
# P. 702 why futures can differ from forwards
# pages going forward:
# - hedging with future
# - potential problems
# - basis risk
# perfect hedge, should nove 1 for 1 with underlying
#
# #### The Forward market
#
#
# settlement - check out BRD FAQ FX as well as P. 43 FX  {TEAM FXPA:FX SPOT AND FORWARD SETTLEMENT DATES <GO>}
#     CLFUSD correct. The Chilean Unidad de Fomento (UF) is a real monetary unit based on the inflation rate
#
#   usdtwd frd  it is showing 27/12/2016 as spot date while 26/12/2016 is us holiday (forward date should
# be 28th: t+2) When counting forward to determine a T+2 settlement date for a currency against USD, any day that is a Fed holiday but not a holiday in any other respected calendar is applied toward the settlement date calculation (unless spot itself would fall on the holiday in which case see above). In this case it is holiday in US but not in Taiwan hence 26th should be included in the settlement calculations
#
# The reason is that spot is already the difference 16:58:13 ALEX KOLL : You shared: Capture.PNG[102KB] Show Image (see below)  16:58:31 ANNIE GREBENYUK : Ah, yes. Good point. 16:58:35 ANNIE GREBENYUK : But why? 16:58:45 ALEX KOLL : For GBP you only have 1st of may as a holiday however, JPY has wed -Fr and than the weekend 17:00:43 ALEX KOLL : So Japanese is not affected by the vacation days as it settles spot before them -> however, GBP does not settle on 1st -> thus it would settle on WE where JPY does not settle 17:01:23 ALEX KOLL : So USDJPY -> FD and JN calendar -> No holiday on the 1st -> thus settlement on 2nd 17:02:31 ALEX KOLL : GBPJPY -> holiday on 1st -> would settle on 3rd -> but holiday (4th as well 5th as well ) than weekend so it settles next Monday -> forward is 3 month after spot settlement 17:02:52 ALEX KOLL : FRD and settlement is a beast 17:06:39 ALEX KOLL : There is also {TEAM FXPA:FX SPOT AND FORWARD SETTLEMENT DATES <GO>}
#
#
# ##### Interest Rate Parity
# Covered vs Unvcovered (Carry Trade)
# #### Carry Trade
# Carry trade -> wiki interest rate parity https://en.wikipedia.org/wiki/Interest_rate_parity => FXFA for covered interest rate parity (no arbitrage condition) -> see help page for a graphical representation => FXSW uncovered interest rate parity (carry trade)- equilibrium condition between current and future spot FX  rate and the interest rate differential
#
# ## Inflation and Exchange Rate dynamics
# ![image.png](attachment:image.png)
# [Overshooting model](http://coin.wne.uw.edu.pl/siwinska/Ma_OE7.pdf)
# [Expectation and Exchange Rate Dynamics (Dornbusch)](https://www.journals.uchicago.edu/doi/10.1086/260506)
# Balance of Payments course JKU (for the above)
# - also: this course explains OCU (optimal currency area, and history of FX etc
# ### FX Options
# #### Listed options
# ##### Nasdaq
# P. 715 Hodrick
# ##### CME
# ##### Using options to hedge transaction risk
#
#
#
#
# why quotation in IVOL makes sense http://www.cmegroup.com/trading/fx/vol-quoted-fxoptions.html
#
# BCAL is used in one FX function only.  The reason BCAL exists is that in FX space when calculating forwards from OIS  curve, FX team wanted to undo the OIS pay delay adjustment. {HELP ADSK <GO>}
#
#
# {GDCO } -> source enablement for ALLQ
#
#
# ### OTC options
# P. 731 Hodrick - nice PDF or exchange rate  => next page alse what shape looks like
# - incorporate the CFA level 2 parts here: create chart of PDF with slider and what is cut off
# - incoprorate the sliders of the various strategies I already created
# - exoplain put call parity: simple chart - combine payoffs, see what is left
#
#
# https://core.ac.uk/download/pdf/6671945.pdf brent root searcher for delta to strike
#
#
#
#      Butterfly flat and same wings: Haha, that is tricky -> need same notional on all legs in EUR -> need to set the strike to DNS (from forward ) -> set the two legs with OTMD to the same value
#
# -> and have premium in USD => if GBP: use GBP notional, USD premium, DNS and same OTM
#
# ## Balance of Payments
# ## Purchasing Power Parity

# %% [markdown]
# # FX News
# Client can use TLIV <GO> to stay on top of the decision & vote split, as well as ECST T MPCVRTIN <GO>.
# Finally, the latest survey for the vote split is here: NSN PCJ7LHT25UKH <GO>
#
# { NSN PAX41E6S9729} -> Daily forecast CNY: every day our Bloomberg staff taps traders and market analysts who offer projections for this rate, and we establish an average, as a condition of gathering these estimates, we cannot identify the list of participants.
#
# central bank the date of last rate change? Elanzize, check if client would like this { NSN PCWD00T0AFB5 <GO>}
#
#
#      "The rates are correct. Venezuela announced the discontinuation of the DIPRO reference rate and adoption of DICOM rate, reason why the change in levels. Reference article: NSN {P3E27U3V7U9S <GO>}."
#
#
# { NSN PAX41E6S9729} -> Daily forecast CNY: every day our Bloomberg staff taps traders and market analysts who offer projections for this rate, and we establish an average, as a condition of gathering these estimates, we cannot identify the list of participants.

# %% [markdown]
# # Option pricing
# - the existing code which has the sliders
# - explaining N(d1) and N(d2)
# - a lot about CFA 2: the max loss and gain, breakeven etc of structure
#
# - incorporate DLIB code to show payoff of structures like Digital, Accumulator, TARF etc
# best to use the DLIB ticker and simply share it firmwide

# %% [markdown]
# # Equity
# P. 319 Blanchard: Making sense of (apparent) nonsense
#
#
#
# ## Risk Reduction
# Mathemetics of (international) risk reduction
# Sharpe Ratio (P. 496 Hodrick)
# Improving Sharpe Ratio
# ## Beta calculation
# manually with Covar/ var and explain the OLS in a nutshell (more details in Statistics section)

# %% [markdown]
# # Statistics and math
#
# - provide links to usefull books and websites
#
# [Python for Econometrics(Kevin Sheppard)](https://www.kevinsheppard.com/Python_for_Econometrics)
#
# [QUANTITATIVE ECONOMICS with Python (Thomas Sargent and John Stachurski)](http://quant-econ.net/_static/pdfs/py-quant-econ.pdf)
# - useful books: P.6 Diebold
#
#
#
#
# money multiplier: see P. 552 Hodrick
#
#
# - spurious regression
# - white noise P. 36 Tsay
#
#
#
# ## Forecasting: follow Diebold
# - trend (stochastic and determinsitic)
# - deterministic vs stochastic trend: Kwan forecasting tutorial
# - seasonality
# - cycles
#
# - ARMA:
# stationarity P. 30 Tsay but also Diebold
# - Unit roots
# stationarity and unit roots (see Kwan forecasting handwritten notes)
# - ARIMA
# - GARCH: Volatility modelling -> conditional heteroskedastic models (P.109 Tsay)
#
# ## Parametric vs Nonparametric
#
#
#
# ## Principal Component analysis and Factor models (P. 476 Tsay)
#
#
# [Gilbert Strang MIT explaining Euler's number](https://ocw.mit.edu/resources/res-18-005-highlights-of-calculus-spring-2010/highlights_of_calculus/the-exponential-function/)
#
# [Gilbert Strang MIT Differential Equations and Liner Algebra](https://ocw.mit.edu/resources/res-18-009-learn-differential-equations-up-close-with-gilbert-strang-and-cleve-moler-fall-2015/differential-equations-and-linear-algebra/)
#
#
#
# # simple concepts of Statistik ohne Angst vor Formeln
#
#
# [Gilbert Strang MIT Orthogonal Vectors and Subspace](https://ocw.mit.edu/courses/mathematics/18-06-linear-algebra-spring-2010/video-lectures/lecture-14-orthogonal-vectors-and-subspaces/)
#
#
# [Gilbert Strang Introduction to Linear Algebra](http://math.mit.edu/~gs/linearalgebra/)
# [Gilbert Strang Calculus](https://ocw.mit.edu/resources/res-18-001-calculus-online-textbook-spring-2005/)
#
# ## [David Jerison MIT edX](https://www.edx.org/bio/david-jerison)
# - Intro to Differential equations
# - Differential equations
# - Calculus: Differentiation and Integration
# polynomal is the same as a series, just the latter is infinite
#
#
# # [David Jerison MIT Taylor Series](https://ocw.mit.edu/courses/mathematics/18-01-single-variable-calculus-fall-2006/video-lectures/lecture-38-taylors-series/) - Logarithm, Convergence & Divergence, Power Series and Taylor Series (probable the best explanation ever seen)
# - convergence 27min onwards
# - Taylor series 40min onwards
#
# #General Power Series:
# a_0 + a_1*x +a_2*x^2 ... + a_n*x^n = sum from N=0 to infinity ( a_n*x^n)
# that's what's known as a power series because of x to power of something
# - rule of convergence
# |x|< R (radius of convergence)
# (-R < x < R)
#
# |x| > R  divergence -> |x| = R very delicate (border line and not used here)
#
# |a_nX^N| -> (converges to zero) exponentially fast for |x| <R
# e.g. 1/(1-x)  for |X| <1 or |X| >1
# will be the same for any power series (one case that goes up, or it is going to 0) - not considering the border case where x = 1 (not defined here)
#
# 1+x+x^2+x^3 + .... = 1/(1-x) -> geometric series
# exactly the opposite of the power series -> can read equalities in two directions (left or right side is formula for the other)
#
# - very much like decimal expansion that allows you to represent numbers like the sqrt(2) - decimal expansion gives a handle on all real numbers
# [explanation](https://math.stackexchange.com/questions/409658/can-every-real-number-be-represented-by-a-possibly-infinite-decimal)
# idea of series is that they are flexible enough to represent all sorts of functions -> all functions like e^x, arcsin etc
#
# ## rules for cenvergent power series:
# - just like polynomials:
# add them: f(x) + g(x)
# multiply them f(x)*g(x)
# substitue f(g(x)
# divide them f(x)/g(x)
# last two are interesting for calculus
# d/dx f(x)
# integ f(x)dx
#
# d/dx (a_0 +  a_1*x + a_2* x^2 ...) = a_1 2*a_2*x + 3*a_3*x^2 ...
# integ (a_0 +  a_1*x + a_2* x^2 ...)dx = c (constant) + a_0*x +a_1*X^2/2 + a_2x^3/3 ...
#
#
# ## Taylor's Formula
# f(x)  = sum n0 o inf f^(n)(0)/n!*x^n
# f of x is in terms of derivative of x -> differentiate n times, evaluate at 0 and divide by n factorial and multiply be x to the power of n
# f^(n)(0)/n! = a_n
# ![image.png](attachment:image.png)
# last is third differentiation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - examples:
# e^x  -> if f(x) is e^x  -> all derivatives are the same (e^x)
#
# thus the numerator is very easy as it is just e^x -> evaluated at 0 it is simply 1 -> 1/n! *x^n

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# sinx approx x
# cosx approx 1- x^2/2
#
# ![image.png](attachment:image.png)
#
#
# all the same family
# - sin is all the odd powers with  alternating
# - cos is all even powers with alternationg signs
# - exponantial just collection of factorials

# %% [markdown]
# **Monte Carlo**: run a lot of paths and take average - but there is alwasy noise in that approach and the tradeoff of running more paths, which reduces the confidence interval but resulst in higher computational cost

# %%
import math

# %% [markdown]
# # Variance Swaps
# [simple explanation](https://www.quora.com/What-is-the-difference-between-trading-variance-and-volatility-swaps)
# The variance swap replication is accomplished using a portfolio of options with different strikes. The construction of this portfolio can be understood intuitively in the Black-Scholes model - the sensitivity of a European option to the variance of the underlying asset price depends on the asset price. This "variance vega" is largest when the underlying price is closest to the strike of the option, and is also an increasing function of the strike.
#
# The variance vega of a portfolio of options that replicates the variance swap payoff must be independent of the underlying price. To achieve this, each option has to be weighted by the inverse of the strike squared. [Inverse of strike squared explained](https://quant.stackexchange.com/questions/32951/why-is-the-fair-strike-of-a-variance-swap-called-implied-volatility)
# $\mathbf{K}_{var} =  \frac{2}{T}\Bigg(rT-\Big(\frac{S_0}{S_T}e^{rT}-1\Big)-\log{\frac{S_*}{S_0}}+e^{rT}\int_{0}^{S_*}\frac{1}{K^2}P(K)dK + e^{rT}\int_{S_*}^{\infty}\frac{1}{K^2}C(K)dK \Bigg) \tag{29} \label{formula}$
#
#
# The variance exposure of the portfolio is largely independent of the underlying asset price, as long as the price lies within the range of option strikes. That is, as the spacing between strikes is decreased and the range of strikes in the options portfolio increases, the variance exposure becomes entirely independent of the underlying stock price. The rigorous derivation shows that such a portfolio indeed replicates the payoff of a variance swap.
#
# [Wilmott magazin](https://www.wilmott.com/wp-content/uploads/2016/07/111116_bossu.pdf)

# %% [markdown]
# https://www.oreilly.com/library/view/listed-volatility-and/9781119167914/c09.xhtml
# get at work

# %%
import bqplot

# %% [markdown]
# why C is most important component of GDP
