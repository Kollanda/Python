# %% [markdown]
# # Andrew Lo Finance
#
# [MIT Open Courseware Andrew Lo](https://ocw.mit.edu/courses/sloan-school-of-management/15-401-finance-theory-i-fall-2008/video-lectures-and-slides/)
# not particulalery brilliant but super simple and
# interesting as this course took place exactly at the time of the last financial crisis and Andrew Lo is referencing to the unfolding events all the time

# %% [markdown]
# Define Dollar symbol
# $ \def\dollar{\unicode{x024}} $

# %% [markdown]
# # PV
# [Present Value Relations Lecture](https://ocw.mit.edu/courses/sloan-school-of-management/15-401-finance-theory-i-fall-2008/video-lectures-and-slides/present-value-relations/)
# ![image.png](attachment:image.png)

# %% [markdown]
# Now what is V? Well we said that one example of a V is the market. But is that objective? Is it subjective? Does it work well? How is value determined? And what we're going to do in this lecture and the next one is to take apart this function V in the case of no uncertainty. So remember I told you the **two important factors in financial analysis** that makes finance
# interesting and exciting is **time** and **uncertainty**.
#
# Well it turns out that this actual analysis requires that we pick a base currency. We pick what's called a **numeraire**. A numeraire is a unit of account, or a standard, by which we measure everything.
#
# So apples to apples is the familiar adage that we use. You can't add apples to oranges. Actually, in theory you could. You could make fruit salad. And you need apples, and oranges, and pears, and all that. But for argument's sake, when it comes to money it really doesn't tell you much that you've got 450 blah. You need to have a set of units.
#
# So once you know the exchange rate, and once you pick a base currency, you can combine the thing. The same idea holds true for cashflows at different points in time. Cashflows at different points in time are like different currencies. In order to add them together, you've got to use the appropriate exchange rates.
#
# For the sake of argument, I'm going to just pick, times 0, dollars today as my base currency. So in other words, I want to
# convert every cashflow into the single currency that is today's dollars.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# V_0 is the value of an asset, not the asset itself, which is the sequence of cashflows.
#
# The unanswered question in all of this analysis? Sounds good, right? This is pretty simple stuff. But I pulled something out of the air. What did I pull out of the air?
#
# Where do I get the exchange rates? From the market. You want to see how? I've got a security that pays $\dollar$1 a year from today. It pays $\dollar$1 a year from today. Who will offer me a penny for that piece of paper? Who will offer me $\dollar$0.50 for that piece of paper? $\dollar$0.75 $\dollar$0.80 $\dollar$0.90 $\dollar$0.95 $\dollar$0.97 $\dollar$0.98 Well, all right. $\dollar$0.97 to the dollar. There you go.
# That's the exchange rate right there. We're done. And by the way, I appreciate that. That's a lot of confidence in my credit worthiness. It's only a 3% discount.
#
# We rely on financial markets. Financial markets didn't exist, we can't do this. I'd have to wave my hands and say, well, you can get it from some kind of theoretical source. You just make it up. Just come up with some numbers. That doesn't sound very compelling. And in fact, it's not. The power of financial markets is the wisdom of the crowds.
#
# Notice that these exchange rates are sometimes called discount factors. The reason they're called discount factors is because typically they are numbers that are less than 1
#
# The question is, what are you discounting if there's no uncertainty? Why should $\dollar$1 next year be worth less than $\dollar$1 today?
# Because there's no uncertainty. I've ruled out uncertainty, right? So there's no default risk. It's impatience. People want to consume now versus later.
#
# But I want to summarize by telling you what we've learned so far. We've learned that we can value cashflows-- assets, which are sequences of cashflows. And the way we value that is by making some implicit assumptions. The assumptions are we know the cashflows in advance, so there's no uncertainty about what the cashflows are. Second, we know the exchange rates. And if you don't know them, go get them. Where do you get them? You get them from the marketplace. And finally, there are no frictions in the currency conversions.

# %% [markdown]
# ![image.png](attachment:image.png)
# **Market gives us many r's**.
# Imperfect but it works pretty well. That said, obviously there are mistakes (misvalutaions) made but so far no one figure out a better way to do this.
# And now, with this definition of r, this opportunity, cost of capital, this interest rate, this discount rate, cost of capital, user cost, discount factor - which we get from the market we then have an expression for what this value operator ought to be. Using this expression, any cashflow in the world can be valued under
# perfect certainty and under the assumptions that we described. Any cashflow can be valued, therefore any asset can be valued.
#
# 1 over 1 plus r. Remember, r is a number greater than 0. So 1 over 1 plus r is a number less than 1, like $0.97 to the dollar. So the exchange rate between next year's dollar and today's dollar is 1 over 1 plus r.
#
# So what we've done in the space of a lecture is to create a valuation operator that works for virtually anything under the sun in certain simplified circumstances. That's a major achievement. Y

# %% [markdown]
# Finance basics:
# - Perpetuity
# ![image.png](attachment:image.png)

# %% [markdown]
# - Annuity: mortgage payments, loans, etc
# ![image.png](attachment:image.png)

# %% [markdown]
# - ADF: Annuity discount factor
#  ![image.png](attachment:image.png)
#
# seperates the interest rate from the cashflow
# left hand side: amount you are boworring
# reight hand side: monthly payment
# precvailing interest rate is r

# %% [markdown]
# # Daycount conventions
# almost all interest rates are quoted in annual interest rates
# market conventions differ though:
# assume 5% for a year, withdraw it in since months and get 5 months, you can reinvest, but it is more than 10 percent now
# - good if you deposit as yo get more
# - bad if you take a loan as you pay more: concept of **APR** (annual percentage rate: 10 % stated rate) or **EAR*** (effective annual rate which includes interest in the interest)
# **bank rate is daily compounding**: also useful as you can take it out on a daily basis - no need for custom computations
# - the more frequently you compound, the higher it is
# ![image.png](attachment:image.png)
# if r is compounded monthly, n is 12
# - show how to convert to continous compounding

# %% [markdown]
# # get leverage explanation:
# 100.000 downpayment for 500.000 home - leverage is 5:1
# - if 10% down in house price, you lost 50.000 of your 100.000
# - Lehman was 16:1 -> so if the value of your assets declines, you wipe out your capital quickly
# - risky if it can actually wipe you out: short term fluctuations (volatility) are not bad if they are within a certain range
#
# ![image.png](attachment:image.png)
# Shows idea of stock market: huge fluctuations possible
# Fixed costs give rise to operating leverage
#
# Extra dollar of revenue translates largely into profits once interest % fixed costs are paid (works in other direction as well (why stocks are so volatile)

# %% [markdown]
# # Inflation
# purchasing power of you money can vary over time, irrespective of the time value of money
# ![image.png](attachment:image.png)
# - nominal return is in name only: how many dollars
# - real return: accounts for cost of living - how much do you actually get

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - Nominal cashlfows should be denominated by nominal discount rates (most frequently used)
# - Real Cashflows should be denominated by reald discount rates

# %% [markdown]
# # Fixed Income
# Cashflows are fixed and predetermined: even if based on variable rate, it still has fixed, preset payments
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - size of fixed income securities dwarfs the equity market
# - but no organized bond exchange: they are traded but less liquid per paper
# CDOs etc, anything highly complex trades even ess frequently

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Coupon: early days it was literally a coupon attached that you mailed in whenever payment was due.

# %% [markdown]
# # term structure of interest rates = Yield curve
# zero curves in reality not readily available for longer maturities - stripping them

# %% [markdown]
# ![image.png](attachment:image.png)
# **T roots** are available (for T different interest rates r) and not guaranteed to have real solution: but for bonds there is usually a real number
# - coupon all positive
# - principal is positive
# - price is positive
# some cases there are multiple solutions
# ### Yield curve
# plots the y for the coupon bonds

# %% [markdown]
# ![image.png](attachment:image.png)
# - Expectations hypothesis implies that yield curve is flat
# - liquidity preference says it should be upward sloping: need to pay extra for people to give up money longer
# - preferred maturities of people, less preferred will come at a premium

# %% [markdown]
# # Measures of interest rate risk

# %% [markdown]
# Breaking the buck: you do not even get your buck (dollar) back
# - money market funds (savinds accounts, deposits etc)
# - if there is a bank run, we will see mass failures
# - no bank can survive that
# - self fulfilling prophecy
# Stampede analogy in movies with bullafos: cannot just say, hold on, wait a minute, let us calm down
# - people moved into short term treasury bills: and everyone can do this - treasurydirect.gov

# %% [markdown]
# # Warren Buffett bought 5 billion dollars of Goldman Sachs
# - **Nomura** buying parts of Lehman: there were very talented professionals and very profiatbale parts of Lehman
# - big shakeup but created a lot of opportunities as well
# - graduates no problem usually: young, hard working and cheap

# %% [markdown]
# # Law of one price: very important principle
# - arbitrage
# - leverage
# - short selling
# - relative prices
# 2 identical cashflows mus have the same price -> also, remember an asset is the sum of future cashflows
# - only assumption needed is that one person in the economy prefers more money over less
#
#
# 2 equation and 2 unknowns, one solution
# - if 3 equations and 2 unknowns, 1 solution only sufficient if the 3rd one is a linear combination of any of the other two: if the 3rd bond is not satisfied by the relationship of the two other equations is evidence of mispricing (arbitrage)
# - if many unkonwns and some unknowns: need linear algebra, eigenvalues etc.
# = fixed income arbitrage

# %% [markdown]
# # Duration
# ![image.png](attachment:image.png)
# The longer the maturity of a bond, the more sensitive it is to the yield
# - the higher the power, the more impact it has (logic explanation)
#
# pure discount bond, duration is simply 30 years
# - else it is a weighted average of the coupon payments (some weight to early years as well)
# weight (sums to 1) is the proportion of present value of casfhlow on that date
# ### sensitivity: a change in yield has impact on bond price of?
# Modified duration: negative number indicates that there is an inverse relationship between yield and price

# %% [markdown]
# ![image.png](attachment:image.png)
# simply CF, Present value of CF and weithted by time

# %% [markdown]
# # Convexity
# ![image.png](attachment:image.png)
# second derivative
# $V_m$ is percentage change in the first derivative

# %% [markdown]
# #### Taylor series approximation of non linear relationships with polynomials
# ![image.png](attachment:image.png)
# today you can use a spreadsheet to calculate the actual change - but back in the days doing it quickly was tough: approximation was needed and helpful
#
# FI is more mathematical as the underlying CF is simple: equity so many factors that affect the outcome (so equity at least historically a lot less sophisticated methods)
#
# - $V_m$ is the second derivative: if change in yield goes up, all else equal makes bonds more valuable => if volatility goes up, bonds are nore valuable (option like characteristics of bonds)
